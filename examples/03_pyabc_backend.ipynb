# %% [markdown]
# # Using the pyABC backend

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this example, we will re-use the logistic growth problem from before, but configure it to perform likelihood-free Bayesian inference. <br>
# The process for instantiating the backend is identical to `ScipyBackend`.
# If the don't provide priors, the `pyABCBackend` will construct log-normal priors with a constant `sigma` around the initial values.

# %%
from logistic_growth import prob
from mempyfit import pyABCBackend

abc = pyABCBackend(prob)
abc.plot_priors()
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<Axes: xlabel='r', ylabel='Prior density'>, <Axes: xlabel='K'>],
#        dtype=object))

# %% [markdown]
# We can `max_total_nr_simulations` to be suitable to our inference problem.

# %%
abc.run(max_total_nr_simulations = 50_000)
# Out:
# ABC.Sampler INFO: Parallelize sampling on 8 processes.
# ABC.History INFO: Start <ABCSMC id=1, start_time=2026-08-24 10:49:26>
# ABC INFO: Calibration sample t = -1.
# ABC INFO: t: 0, eps: 2.61209293e+00.
# ABC INFO: Accepted: 1000 / 2130 = 4.6948e-01, ESS: 1.0000e+03.
# ABC INFO: t: 1, eps: 7.77789291e-01.
# ABC INFO: Accepted: 1000 / 3300 = 3.0303e-01, ESS: 9.3330e+02.
# ABC INFO: t: 2, eps: 4.22881265e-01.
# ABC INFO: Accepted: 1000 / 4523 = 2.2109e-01, ESS: 8.5149e+02.
# ABC INFO: t: 3, eps: 2.81791473e-01.
# ABC INFO: Accepted: 1000 / 6120 = 1.6340e-01, ESS: 7.4069e+02.
# ABC INFO: t: 4, eps: 2.31453245e-01.
# ABC INFO: Accepted: 1000 / 9562 = 1.0458e-01, ESS: 5.8837e+02.
# ABC INFO: t: 5, eps: 2.02736556e-01.
# ABC INFO: Accepted: 1000 / 8545 = 1.1703e-01, ESS: 8.2603e+02.
# ABC INFO: t: 6, eps: 1.70843759e-01.
# ABC INFO: Accepted: 1000 / 2894 = 3.4554e-01, ESS: 9.3958e+02.
# ABC INFO: t: 7, eps: 1.48288885e-01.
# ABC INFO: Accepted: 1000 / 2281 = 4.3840e-01, ESS: 9.9093e+02.
# ABC INFO: t: 8, eps: 1.33702018e-01.
# ABC INFO: Accepted: 1000 / 2100 = 4.7619e-01, ESS: 9.9096e+02.
# ABC INFO: t: 9, eps: 1.25988016e-01.
# ABC INFO: Accepted: 1000 / 2058 = 4.8591e-01, ESS: 9.9185e+02.
# ABC INFO: Stop: Maximum number of generations.
# ABC.History INFO: Done <ABCSMC id=1, duration=0:00:19.719217, end_time=2026-08-24 10:49:46>
# Conducted Bayesian inference using SMC-ABC. Results are in `abc_history` and `accepted`

# %%
# TODO: update figwarks_marginaldists
report = abc.report()
# Out:
# /home/hansul/mem25/lib/mempyfit/mempyfit/backend_pyabc.py:358: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[0].legend()
# #### ---- Posterior distributions ---- ####
# #### ---- Posterior summary ---- ####
#   param    median       p05       p25       p75       p95
# 0     r  0.137915  0.120210  0.128133  0.148493  0.159026
# 1     K  0.241936  0.228802  0.234650  0.250077  0.259256
#
# #### ---- Visual check ---- ####
