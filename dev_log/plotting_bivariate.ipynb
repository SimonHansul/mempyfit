# %%
from mempyfit import Dataset
import numpy as np
from multipledispatch import dispatch

data = Dataset()

data.add(
    name = 'tXN', 
    value = np.array([
        [0, 0, 0],
        [1, 0, 1],
        [2, 0, 4],
        [3, 0, 6],
        [0, 1, 0],
        [1, 1, 2],
        [2, 1, 8],
        [3, 1, 12], 
    ]), 
    labels = ['t', 'group', 'N'], 
    units = ['d', '-', '#']
)

fig, ax = data.plot('tXN')
