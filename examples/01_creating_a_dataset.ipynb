# %% [markdown]
# # Creating a `Dataset` and populating it with data

# %%
from mempyfit import *

# %% [markdown]
# We can start by instantiating an empty `Dataset`:

# %%
ds = Dataset()

# %% [markdown]
# Now we succesively add entries.
# The process is somewhat similar to what is done in AmPtool, with some (intended) syntactical differences. <br>
#
# Below is the minimum amount of information that we need to enter:

# %%
ds.add(
    name = 'N_max',
    value = 100,
    units = '#',
    labels = 'maximum cell abundance',
)

# %% [markdown]
# This just adds a single data point, what we refer to as "zerovariate".

# %% [markdown]
# The entered `value` can have any shape though.

# %%
ds.add(
    name = 'tN', 
    value = np.array([
        [0, 0.1], 
        [1, 0.2], 
        [3, 0.4],
        [4, 0.45], 
        [5, 0.475]
    ]), 
    units = ['d', '#'], 
    labels = ['time', 'cell count']
)

# %% [markdown]
# By default, `mempyfit` will assume that matrices are column-oriented. That is meaning to say, each column is a different variable, and each row is a different observation.
#
# It is possible to ignore these defaults, but it means more work.
#
# Also, we assume that the last column is the dependent variable, and (for now) that each entry has exactly one dependent variable. This also follows the add-my-pet style of entering data.

# %%
ds.add(
    name = 't-TN', 
    value = np.array([
        [0, 25, 0.1], 
        [1, 25, 0.2], 
        [3, 25, 0.4],
        [4, 25, 0.45], 
        [5, 25, 0.475], 
        [0, 27.5, 0.1], 
        [1, 27.5, 0.25], 
        [3, 27.5, 0.45],
        [4, 27.5, 0.475], 
        [5, 27.5, 0.48]
    ]), 
    units = ['d', '°C', '#'], 
    labels = ['time', 'temperature', 'cell count']
)

# %% [markdown]
# Printing the dataset will give us an overview over what we have added:

# %%
ds
# Out:
# <Dataset with 3 entries>
#   1. N_max (ZEROVARIATE) [['#']] @ nan K
#   2. tN (UNIVARIATE) [['d', '#']] @ nan K
#   3. t-TN (MULTIVARIATE) [['d', '°C', '#']] @ nan K

# %% [markdown]
# We can also retrieve the information on a specific entry,

# %%
ds.getinfo('t-TN')
# Out:
# OrderedDict([('name', 't-TN'),
#              ('value', array([[ 0.   , 25.   ,  0.1  ],
#                      [ 1.   , 25.   ,  0.2  ],
#                      [ 3.   , 25.   ,  0.4  ],
#                      [ 4.   , 25.   ,  0.45 ],
#                      [ 5.   , 25.   ,  0.475],
#                      [ 0.   , 27.5  ,  0.1  ],
#                      [ 1.   , 27.5  ,  0.25 ],
#                      [ 3.   , 27.5  ,  0.45 ],
#                      [ 4.   , 27.5  ,  0.475],
#                      [ 5.   , 27.5  ,  0.48 ]])),
#              ('units', ['d', '°C', '#']),
#              ('labels', ['time', 'temperature', 'cell count']),
#              ('title', ''),
#              ('temperature', nan),
#              ('temperature_units', 'K'),
#              ('dimensionality_type', 'MULTIVARIATE'),
#              ('bibkey', ''),
#              ('comment', '')])

# %% [markdown]
# , or just the value:

# %%
ds['t-TN']
# Out:
# array([[ 0.   , 25.   ,  0.1  ],
#        [ 1.   , 25.   ,  0.2  ],
#        [ 3.   , 25.   ,  0.4  ],
#        [ 4.   , 25.   ,  0.45 ],
#        [ 5.   , 25.   ,  0.475],
#        [ 0.   , 27.5  ,  0.1  ],
#        [ 1.   , 27.5  ,  0.25 ],
#        [ 3.   , 27.5  ,  0.45 ],
#        [ 4.   , 27.5  ,  0.475],
#        [ 5.   , 27.5  ,  0.48 ]])

# %% [markdown]
# See below for all arguments that can be passed on to the `add` method.

# %%
help(ds.add)
# Out:
# Help on method add in module mempyfit.dataset:
#
# add(name: str, value, units=None, labels=None, error_model: <built-in function callable> = <dispatched sumofsquares>, title: str = '', temperature: float = nan, temperature_unit: str = 'K', dimensionality_type: mempyfit.dataset.DimensionalityType | None = None, bibkey: str = '', comment: str = '') -> None method of mempyfit.dataset.Dataset instance
#     Add a data entry to a dataset.
#     Minimum information needed are
#     - name
#     - value
#     - units
#     - labels
#
#     Args:
#         name (str): Label of the data entry.
#         value: Numeric scalar or numpy array for the data.
#         units (str or list[str], optional): Units for the data entry.
#         labels (str or list[str], optional): Axis labels for the data entry.
#         error_model (callable, optional): Error model used for fitting.
#         title (str, optional): Plot title for the dataset entry.
#         temperature (float, optional): Temperature associated with the data.
#         temperature_unit (str, optional): Unit of temperature.
#         dimensionality_type (DimensionalityType | None, optional): Explicit dimensionality type.
#         bibkey (str, optional): Bibliography key for the data source.
#         comment (str, optional): Comments about the data.
#
#     Returns:
#         None
#
#     Example:
#         >>> dataset.add('conc', np.array([[0,1],[1,2]]), units=['h','mg/L'], labels=['time','conc'])
