# %% [markdown]
# # Using the pyABC backend

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this example, we will re-use the logistic growth problem from before, but configure it to perform likelihood-free Bayesian inference. <br>
# The process for instantiating the backend is identical to `ScipyBackend`.
# If the don't provide priors, the `pyABCBackend` will construct log-normal priors with a constant `sigma` around the initial values.

# %%
from logistic_growth import prob
from mempyfit import pyABCBackend

abc = pyABCBackend(prob)
abc.plot_priors()
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<Axes: xlabel='r', ylabel='Prior density'>, <Axes: xlabel='K'>],
#        dtype=object))

# %% [markdown]
# We can `max_total_nr_simulations` to be suitable to our inference problem.

# %%
abc.run(max_total_nr_simulations = 50_000)
# Out:
# ABC.Sampler INFO: Parallelize sampling on 8 processes.
# ABC.History INFO: Start <ABCSMC id=10, start_time=2026-08-18 18:16:02>
# ABC INFO: Calibration sample t = -1.
# ABC INFO: t: 0, eps: 3.34801694e+00.
# ABC INFO: Accepted: 1000 / 1957 = 5.1099e-01, ESS: 1.0000e+03.
# ABC INFO: t: 1, eps: 9.43551800e-01.
# ABC INFO: Accepted: 1000 / 3070 = 3.2573e-01, ESS: 8.5168e+02.
# ABC INFO: t: 2, eps: 4.85173025e-01.
# ABC INFO: Accepted: 1000 / 4671 = 2.1409e-01, ESS: 9.4318e+02.
# ABC INFO: t: 3, eps: 2.97098194e-01.
# ABC INFO: Accepted: 1000 / 6076 = 1.6458e-01, ESS: 8.4539e+02.
# ABC INFO: t: 4, eps: 2.35802968e-01.
# ABC INFO: Accepted: 1000 / 8332 = 1.2002e-01, ESS: 5.6053e+02.
# ABC INFO: t: 5, eps: 2.06052095e-01.
# ABC INFO: Accepted: 1000 / 14469 = 6.9113e-02, ESS: 7.5725e+02.
# ABC INFO: t: 6, eps: 1.76961881e-01.
# ABC INFO: Accepted: 1000 / 3097 = 3.2289e-01, ESS: 9.3196e+02.
# ABC INFO: t: 7, eps: 1.52644955e-01.
# ABC INFO: Accepted: 1000 / 2330 = 4.2918e-01, ESS: 9.8115e+02.
# ABC INFO: t: 8, eps: 1.37136795e-01.
# ABC INFO: Accepted: 1000 / 2215 = 4.5147e-01, ESS: 9.8047e+02.
# ABC INFO: t: 9, eps: 1.28106285e-01.
# ABC INFO: Accepted: 1000 / 1986 = 5.0352e-01, ESS: 9.8958e+02.
# ABC INFO: Stop: Maximum number of generations.
# ABC.History INFO: Done <ABCSMC id=10, duration=0:00:22.177496, end_time=2026-08-18 18:16:24>
# Conducted Bayesian inference using SMC-ABC. Results are in `abc_history` and `accepted`

# %%
# TODO: update figwarks_marginaldists
report = abc.report()
# Out:
# #### ---- Posterior distributions ---- ####
# /home/hansul/mem25/lib/mempyfit/mempyfit/backend_pyabc.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   """
# #### ---- Posterior summary ---- ####
#   param    median       p05       p25       p75       p95
# 0     r  0.138161  0.116522  0.126982  0.149096  0.161968
# 1     K  0.242492  0.227299  0.234004  0.252294  0.262836
#
# #### ---- Visual check ---- ####
