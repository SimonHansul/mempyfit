# %%
from mempyfit import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from mempyfit import *
#
# File c:\Users\simon\.julia\conda\3\envs\mempyfit_test\Lib\site-packages\mempyfit\__init__.py:2
#       1 from .dataset import *
# ----> 2 from .modelfit import *
#
# ModuleNotFoundError: No module named 'mempyfit.modelfit'

# %%
Dataset
